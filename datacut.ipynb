# %%
import sys
print(sys.executable)
# Out:
# C:\Users\eduar\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe

# %%
! "Change with your path shown above" -m pip install pandas
# Out:
# 'sys.executable' n�o � reconhecido como um comando interno
# ou externo, um programa oper�vel ou um arquivo em lotes.

# %%
import os
import pandas as pd

# Ensure the file path is correct

file = r"data\taylor\taylor.csv"

# Check if the file exists
if not os.path.exists(file):
    raise FileNotFoundError(f"File not found: {file}")


# Read the CSV file with the appropriate encoding
try:
    df_taylor = pd.read_csv(file, encoding='latin1')
except UnicodeDecodeError:
    df_taylor = pd.read_csv(file, encoding='iso-8859-1')

# Exclude rows where the 'Tour' column value matches any of the specified values
tours_to_exclude = ['Fearless_Tour', 'Speak_Now_World_Tour', 'The_Red_Tour', 'The_1989_World_Tour']
df_taylor = df_taylor[~df_taylor['Tour'].isin(tours_to_exclude)]

# Print the updated DataFrame

# %%
df_taylor.insert(0, "main_attraction", "Taylor Swift")

# %%
import json
df_taylor
# Out:
#     main_attraction             City        Country  \
# 392    Taylor Swift         Glendale  United States
# 393    Taylor Swift      Santa Clara  United States
# 394    Taylor Swift      Santa Clara  United States
# 395    Taylor Swift         Pasadena  United States
# 396    Taylor Swift         Pasadena  United States
# 397    Taylor Swift          Seattle  United States
# 398    Taylor Swift           Denver  United States
# 399    Taylor Swift          Chicago  United States
# 400    Taylor Swift          Chicago  United States
# 401    Taylor Swift       Manchester        England
# 402    Taylor Swift       Manchester        England
# 403    Taylor Swift           Dublin        Ireland
# 404    Taylor Swift           Dublin        Ireland
# 405    Taylor Swift           London        England
# 406    Taylor Swift           London        England
# 407    Taylor Swift       Louisville  United States
# 408    Taylor Swift         Columbus  United States
# 409    Taylor Swift         Landover  United States
# 410    Taylor Swift         Landover  United States
# 411    Taylor Swift     Philadelphia  United States
# 412    Taylor Swift     Philadelphia  United States
# 413    Taylor Swift        Cleveland  United States
# 414    Taylor Swift  East Rutherford  United States
# 415    Taylor Swift  East Rutherford  United States
# 416    Taylor Swift  East Rutherford  United States
# 417    Taylor Swift       Foxborough  United States
# 418    Taylor Swift       Foxborough  United States
# 419    Taylor Swift       Foxborough  United States
# 420    Taylor Swift          Toronto         Canada
# 421    Taylor Swift          Toronto         Canada
# 422    Taylor Swift       Pittsburgh  United States
# 423    Taylor Swift          Atlanta  United States
# 424    Taylor Swift          Atlanta  United States
# 425    Taylor Swift            Tampa  United States
# 426    Taylor Swift    Miami Gardens  United States
# 427    Taylor Swift        Nashville  United States
# 428    Taylor Swift          Detroit  United States
# 429    Taylor Swift      Minneapolis  United States
# 430    Taylor Swift      Minneapolis  United States
# 431    Taylor Swift      Kansas City  United States
# 432    Taylor Swift     Indianapolis  United States
# 433    Taylor Swift        St. Louis  United States
# 434    Taylor Swift      New Orleans  United States
# 435    Taylor Swift          Houston  United States
# 436    Taylor Swift        Arlington  United States
# 437    Taylor Swift        Arlington  United States
# 438    Taylor Swift            Perth      Australia
# 439    Taylor Swift        Melbourne      Australia
# 440    Taylor Swift           Sydney      Australia
# 441    Taylor Swift         Brisbane      Australia
# 442    Taylor Swift         Auckland    New Zealand
# 443    Taylor Swift            Tokyo          Japan
# 444    Taylor Swift            Tokyo          Japan
#
#                                    Venue                Opening act(s)  \
# 392        University of Phoenix Stadium  Camila Cabello\r\nCharli XCX
# 393                       Levi's Stadium  Camila Cabello\r\nCharli XCX
# 394                       Levi's Stadium  Camila Cabello\r\nCharli XCX
# 395                            Rose Bowl  Camila Cabello\r\nCharli XCX
# 396                            Rose Bowl  Camila Cabello\r\nCharli XCX
# 397                    CenturyLink Field                    Charli XCX
# 398  Sports Authority Field at Mile High  Camila Cabello\r\nCharli XCX
# 399                        Soldier Field  Camila Cabello\r\nCharli XCX
# 400                        Soldier Field  Camila Cabello\r\nCharli XCX
# 401                       Etihad Stadium  Camila Cabello\r\nCharli XCX
# 402                       Etihad Stadium  Camila Cabello\r\nCharli XCX
# 403                           Croke Park  Camila Cabello\r\nCharli XCX
# 404                           Croke Park  Camila Cabello\r\nCharli XCX
# 405                      Wembley Stadium  Camila Cabello\r\nCharli XCX
# 406                      Wembley Stadium  Camila Cabello\r\nCharli XCX
# 407                     Cardinal Stadium  Camila Cabello\r\nCharli XCX
# 408                         Ohio Stadium  Camila Cabello\r\nCharli XCX
# 409                           FedExField  Camila Cabello\r\nCharli XCX
# 410                           FedExField  Camila Cabello\r\nCharli XCX
# 411              Lincoln Financial Field  Camila Cabello\r\nCharli XCX
# 412              Lincoln Financial Field  Camila Cabello\r\nCharli XCX
# 413                  FirstEnergy Stadium  Camila Cabello\r\nCharli XCX
# 414                      MetLife Stadium  Camila Cabello\r\nCharli XCX
# 415                      MetLife Stadium  Camila Cabello\r\nCharli XCX
# 416                      MetLife Stadium  Camila Cabello\r\nCharli XCX
# 417                     Gillette Stadium  Camila Cabello\r\nCharli XCX
# 418                     Gillette Stadium  Camila Cabello\r\nCharli XCX
# 419                     Gillette Stadium  Camila Cabello\r\nCharli XCX
# 420                        Rogers Centre  Camila Cabello\r\nCharli XCX
# 421                        Rogers Centre  Camila Cabello\r\nCharli XCX
# 422                          Heinz Field  Camila Cabello\r\nCharli XCX
# 423                Mercedes-Benz Stadium  Camila Cabello\r\nCharli XCX
# 424                Mercedes-Benz Stadium  Camila Cabello\r\nCharli XCX
# 425                Raymond James Stadium  Camila Cabello\r\nCharli XCX
# 426                    Hard Rock Stadium  Camila Cabello\r\nCharli XCX
# 427                       Nissan Stadium  Camila Cabello\r\nCharli XCX
# 428                           Ford Field  Camila Cabello\r\nCharli XCX
# 429                    U.S. Bank Stadium  Camila Cabello\r\nCharli XCX
# 430                    U.S. Bank Stadium  Camila Cabello\r\nCharli XCX
# 431                    Arrowhead Stadium  Camila Cabello\r\nCharli XCX
# 432                    Lucas Oil Stadium  Camila Cabello\r\nCharli XCX
# 433         The Dome at America's Center  Camila Cabello\r\nCharli XCX
# 434              Mercedes-Benz Superdome  Camila Cabello\r\nCharli XCX
# 435                          NRG Stadium  Camila Cabello\r\nCharli XCX
# 436                         AT&T Stadium  Camila Cabello\r\nCharli XCX
# 437                         AT&T Stadium  Camila Cabello\r\nCharli XCX
# 438                        Optus Stadium          Charli XCX\r\nBroods
# 439                       Marvel Stadium          Charli XCX\r\nBroods
# 440                          ANZ Stadium          Charli XCX\r\nBroods
# 441                            The Gabba          Charli XCX\r\nBroods
# 442                  Mount Smart Stadium          Charli XCX\r\nBroods
# 443                           Tokyo Dome                    Charli XCX
# 444                           Tokyo Dome                    Charli XCX
#
#     Attendance (tickets sold / available)      Revenue  \
# 392                       59,157 / 59,157   $7,214,478
# 393                     107,550 / 107,550  $14,006,963
# 394                     107,550 / 107,550  $14,006,963
# 395                     118,084 / 118,084  $16,251,980
# 396                     118,084 / 118,084  $16,251,980
# 397                       56,021 / 56,021   $8,672,219
# 398                       57,140 / 57,140   $7,926,366
# 399                     105,208 / 105,208  $14,576,697
# 400                     105,208 / 105,208  $14,576,697
# 401                       77,258 / 77,258   $6,169,724
# 402                       77,258 / 77,258   $6,169,724
# 403                     133,034 / 133,034   $8,567,769
# 404                     133,034 / 133,034   $8,567,769
# 405                     143,427 / 143,427  $12,214,933
# 406                     143,427 / 143,427  $12,214,933
# 407                       52,138 / 52,138   $4,928,219
# 408                       62,897 / 62,897   $6,606,529
# 409                       95,672 / 95,672  $11,396,004
# 410                       95,672 / 95,672  $11,396,004
# 411                     107,378 / 107,378  $11,951,047
# 412                     107,378 / 107,378  $11,951,047
# 413                       51,323 / 51,323   $5,148,757
# 414                     165,654 / 165,654  $22,031,386
# 415                     165,654 / 165,654  $22,031,386
# 416                     165,654 / 165,654  $22,031,386
# 417                     174,764 / 174,764  $21,779,846
# 418                     174,764 / 174,764  $21,779,846
# 419                     174,764 / 174,764  $21,779,846
# 420                     100,310 / 100,310  $11,177,000
# 421                     100,310 / 100,310  $11,177,000
# 422                       56,445 / 56,445   $6,230,876
# 423                     116,746 / 116,746  $18,089,415
# 424                     116,746 / 116,746  $18,089,415
# 425                       55,909 / 55,909   $7,244,264
# 426                       47,818 / 47,818   $7,072,164
# 427                       56,112 / 56,112   $9,007,179
# 428                       49,464 / 49,464   $6,597,852
# 429                       98,774 / 98,774  $10,242,024
# 430                       98,774 / 98,774  $10,242,024
# 431                       58,611 / 58,611   $6,730,138
# 432                       55,729 / 55,729   $6,531,245
# 433                       47,831 / 47,831   $4,884,054
# 434                       53,172 / 53,172   $6,491,546
# 435                       53,800 / 53,800   $9,350,275
# 436                     105,002 / 105,002  $15,006,157
# 437                     105,002 / 105,002  $15,006,157
# 438                       50,891 / 50,891   $4,153,658
# 439                       63,027 / 63,027   $6,755,570
# 440                       72,805 / 72,805   $7,686,564
# 441                       43,907 / 43,907   $4,338,127
# 442                       35,749 / 35,749   $3,617,593
# 443                     100,109 / 100,109  $14,859,847
# 444                     100,109 / 100,109  $14,859,847
#
#                         Tour
# 392  Reputation_Stadium_Tour
# 393  Reputation_Stadium_Tour
# 394  Reputation_Stadium_Tour
# 395  Reputation_Stadium_Tour
# 396  Reputation_Stadium_Tour
# 397  Reputation_Stadium_Tour
# 398  Reputation_Stadium_Tour
# 399  Reputation_Stadium_Tour
# 400  Reputation_Stadium_Tour
# 401  Reputation_Stadium_Tour
# 402  Reputation_Stadium_Tour
# 403  Reputation_Stadium_Tour
# 404  Reputation_Stadium_Tour
# 405  Reputation_Stadium_Tour
# 406  Reputation_Stadium_Tour
# 407  Reputation_Stadium_Tour
# 408  Reputation_Stadium_Tour
# 409  Reputation_Stadium_Tour
# 410  Reputation_Stadium_Tour
# 411  Reputation_Stadium_Tour
# 412  Reputation_Stadium_Tour
# 413  Reputation_Stadium_Tour
# 414  Reputation_Stadium_Tour
# 415  Reputation_Stadium_Tour
# 416  Reputation_Stadium_Tour
# 417  Reputation_Stadium_Tour
# 418  Reputation_Stadium_Tour
# 419  Reputation_Stadium_Tour
# 420  Reputation_Stadium_Tour
# 421  Reputation_Stadium_Tour
# 422  Reputation_Stadium_Tour
# 423  Reputation_Stadium_Tour
# 424  Reputation_Stadium_Tour
# 425  Reputation_Stadium_Tour
# 426  Reputation_Stadium_Tour
# 427  Reputation_Stadium_Tour
# 428  Reputation_Stadium_Tour
# 429  Reputation_Stadium_Tour
# 430  Reputation_Stadium_Tour
# 431  Reputation_Stadium_Tour
# 432  Reputation_Stadium_Tour
# 433  Reputation_Stadium_Tour
# 434  Reputation_Stadium_Tour
# 435  Reputation_Stadium_Tour
# 436  Reputation_Stadium_Tour
# 437  Reputation_Stadium_Tour
# 438  Reputation_Stadium_Tour
# 439  Reputation_Stadium_Tour
# 440  Reputation_Stadium_Tour
# 441  Reputation_Stadium_Tour
# 442  Reputation_Stadium_Tour
# 443  Reputation_Stadium_Tour
# 444  Reputation_Stadium_Tour

# %%
json_documents = df_taylor.to_dict(orient='records')
total_files = len(json_documents)


output_folder = 'json_files'
os.makedirs(output_folder, exist_ok=True)

#Each JSON document to a separate file in the specified folder
for i, doc in enumerate(json_documents):
    file_name = f'document_{i + 1}.json'
    file_path = os.path.join(output_folder, file_name)
    with open(file_path, 'w') as f:
        json.dump(doc, f, indent=4)



print(f'{total_files} files have been created.')
# Out:
# 53 files have been created.

# %% [markdown]
# #METALLICA

# %%
metallica_file = r"data\metallica\Metallica_gigs.csv"

if not os.path.exists(metallica_file):
    raise FileNotFoundError(f"File not found: {metallica_file}")

df_metallica = pd.read_csv(metallica_file, sep=';')

# %%
df_metallica.insert(1, "main_attraction", "Metallica")
df_metallica['Date'] = pd.to_datetime(df_metallica['Date'])

# %%
df_metallica = df_metallica[df_metallica['Date'].dt.year >= 2018]

# %%
df_metallica
# Out:
#             Date main_attraction  \
# 29735 2018-02-01       Metallica
# 29736 2018-02-01       Metallica
# 29737 2018-02-01       Metallica
# 29738 2018-02-01       Metallica
# 29739 2018-02-01       Metallica
# ...          ...             ...
# 32443 2023-12-14       Metallica
# 32444 2023-12-14       Metallica
# 32445 2023-12-14       Metallica
# 32446 2023-12-14       Metallica
# 32447 2024-03-20       Metallica
#
#                                                    Event  \
# 29735                                                NaN
# 29736                                                NaN
# 29737                                                NaN
# 29738                                                NaN
# 29739                                                NaN
# ...                                                  ...
# 32443                                Soundstorm Festival
# 32444                                Soundstorm Festival
# 32445                                Soundstorm Festival
# 32446                                Soundstorm Festival
# 32447  The Library of Congress Gershwin Prize for Pop...
#
#                        Venue                                       Location  \
# 29735           Altice Arena                                Lisbon,Portugal
# 29736           Altice Arena                                Lisbon,Portugal
# 29737           Altice Arena                                Lisbon,Portugal
# 29738           Altice Arena                                Lisbon,Portugal
# 29739           Altice Arena                                Lisbon,Portugal
# ...                      ...                                            ...
# 32443                 Banban                            Riyadh,Saudi Arabia
# 32444                 Banban                            Riyadh,Saudi Arabia
# 32445                 Banban                            Riyadh,Saudi Arabia
# 32446                 Banban                            Riyadh,Saudi Arabia
# 32447  DAR Constitution Hall  Washington,District of Columbia,United States
#
#         Latitude  Longitude Is_cancelled  Setlist_no  \
# 29735  38.707751  -9.136592           No           1
# 29736  38.707751  -9.136592           No           2
# 29737  38.707751  -9.136592           No           3
# 29738  38.707751  -9.136592           No           4
# 29739  38.707751  -9.136592           No           5
# ...          ...        ...          ...         ...
# 32443  24.638916  46.716010           No          13
# 32444  24.638916  46.716010           No          14
# 32445  24.638916  46.716010           No          15
# 32446  24.638916  46.716010           No          16
# 32447  38.895037 -77.036543           No           1
#
#                                           Song Is_cover Song_details  \
# 29735                                Hardwired       No          NaN
# 29736                             Atlas, Rise!       No          NaN
# 29737                           Seek & Destroy       No          NaN
# 29738                      Harvester of Sorrow       No          NaN
# 29739                Welcome Home (Sanitarium)       No          NaN
# ...                                        ...      ...          ...
# 32443                           Seek & Destroy       No          NaN
# 32444                                      One       No          NaN
# 32445                        Master of Puppets       No          NaN
# 32446                            Enter Sandman       No          NaN
# 32447  Funeral for a Friend/Love Lies Bleeding      Yes          NaN
#
#                                        Song_profile_link            Tour  \
# 29735     https://www.metallica.com/songs/hardwired.html      WorldWired
# 29736    https://www.metallica.com/songs/atlas-rise.html      WorldWired
# 29737  https://www.metallica.com/songs/seek-and-destr...      WorldWired
# 29738  https://www.metallica.com/songs/harvester-of-s...      WorldWired
# 29739  https://www.metallica.com/songs/welcome-home-s...      WorldWired
# ...                                                  ...             ...
# 32443  https://www.metallica.com/songs/seek-and-destr...  M72 World Tour
# 32444           https://www.metallica.com/songs/one.html  M72 World Tour
# 32445  https://www.metallica.com/songs/master-of-pupp...  M72 World Tour
# 32446  https://www.metallica.com/songs/enter-sandman....  M72 World Tour
# 32447  https://www.metallica.com/songs/funeral-for-a-...             NaN
#
#                                               Other_acts Concert_details  \
# 29735                                          Kvelertak             NaN
# 29736                                          Kvelertak             NaN
# 29737                                          Kvelertak             NaN
# 29738                                          Kvelertak             NaN
# 29739                                          Kvelertak             NaN
# ...                                                  ...             ...
# 32443                                                NaN             NaN
# 32444                                                NaN             NaN
# 32445                                                NaN             NaN
# 32446                                                NaN             NaN
# 32447  Joni Mitchell,Garth Brooks,Brandi Carlile,Anni...             NaN
#
#                                     Concert_profile_link
# 29735  https://www.metallica.com/tour/2018-02-01-lisb...
# 29736  https://www.metallica.com/tour/2018-02-01-lisb...
# 29737  https://www.metallica.com/tour/2018-02-01-lisb...
# 29738  https://www.metallica.com/tour/2018-02-01-lisb...
# 29739  https://www.metallica.com/tour/2018-02-01-lisb...
# ...                                                  ...
# 32443  https://www.metallica.com/tour/2023-12-14-riya...
# 32444  https://www.metallica.com/tour/2023-12-14-riya...
# 32445  https://www.metallica.com/tour/2023-12-14-riya...
# 32446  https://www.metallica.com/tour/2023-12-14-riya...
# 32447  https://www.metallica.com/tour/2024-03-20-wash...
#
# [2708 rows x 17 columns]

# %%
df_metallica['Song'] = df_metallica['Song'].astype(str)
df_metallica['Songs'] = df_metallica.groupby(['Date', 'Event', 'Location', 'Venue'])['Song'].transform(lambda x: ', '.join(x))

# %%
df_metallica.drop_duplicates(subset=['Date', 'Location', 'Venue'], keep='first', inplace=True)
df_metallica.reset_index(drop=True, inplace=True)

# %%
df_metallica = df_metallica.astype(str)

# %%
metallica_culumns_to_exclude = ['Setlist_no', 'Song', 'Is_cover', 'Song_details', 'Song_profile_link']
df_metallica = df_metallica.drop(columns=metallica_culumns_to_exclude)

# %%
df_metallica.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  195 non-null    object
#  1   main_attraction       195 non-null    object
#  2   Event                 195 non-null    object
#  3   Venue                 195 non-null    object
#  4   Location              195 non-null    object
#  5   Latitude              195 non-null    object
#  6   Longitude             195 non-null    object
#  7   Is_cancelled          195 non-null    object
#  8   Tour                  195 non-null    object
#  9   Other_acts            195 non-null    object
#  10  Concert_details       195 non-null    object
#  11  Concert_profile_link  195 non-null    object
#  12  Songs                 195 non-null    object
# dtypes: object(13)
# memory usage: 19.9+ KB

# %%
json_metallica = df_metallica.to_dict(orient='records')

output_folder = 'json_files'
os.makedirs(output_folder, exist_ok=True)
#Each JSON document to a separate file in the specified folder
for i, doc in enumerate(json_metallica):
    file_name = f'document_{i + total_files}.json'
    file_path = os.path.join(output_folder, file_name)
    with open(file_path, 'w') as f:
        json.dump(doc, f, indent=4)

total_files += len(json_metallica)

print(f'{total_files} files have been created.')
# Out:
# 248 files have been created.
